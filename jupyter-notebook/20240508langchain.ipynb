# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ------------------
# absl-py                       2.0.0
# accelerate                    0.25.0
# addict                        2.4.0
# aiofiles                      23.2.1
# aiohttp                       3.9.1
# aiosignal                     1.3.1
# aliyun-python-sdk-core        2.14.0
# aliyun-python-sdk-kms         2.16.2
# altair                        5.2.0
# annotated-types               0.6.0
# anyio                         3.7.1
# appnope                       0.1.4
# argcomplete                   3.2.1
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asgiref                       3.7.2
# asttokens                     2.4.1
# async-lru                     2.0.4
# async-timeout                 4.0.3
# attrs                         23.1.0
# audioread                     3.0.1
# Babel                         2.15.0
# beautifulsoup4                4.12.3
# bitsandbytes                  0.41.3.post2
# bleach                        6.1.0
# blinker                       1.7.0
# cachetools                    5.3.2
# certifi                       2023.11.17
# cffi                          1.16.0
# chardet                       5.2.0
# charset-normalizer            3.3.2
# chatglm-cpp                   0.3.0
# click                         8.1.7
# colorama                      0.4.6
# coloredlogs                   15.0.1
# comm                          0.2.2
# contourpy                     1.2.0
# crcmod                        1.7
# cryptography                  41.0.7
# cycler                        0.12.1
# Cython                        0.29.37
# dataclasses-json              0.6.5
# datasets                      2.15.0
# debugpy                       1.8.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# dill                          0.3.7
# diskcache                     5.6.3
# distro                        1.9.0
# dnspython                     2.4.2
# editdistance                  0.6.2
# einops                        0.7.0
# email-validator               2.1.0.post1
# exceptiongroup                1.2.0
# executing                     2.0.1
# fastapi                       0.105.0
# fastjsonschema                2.19.1
# ffmpy                         0.3.1
# filelock                      3.13.1
# Flask                         3.0.0
# fonttools                     4.46.0
# fqdn                          1.5.1
# frozenlist                    1.4.1
# fsspec                        2023.10.0
# funasr                        0.8.7
# gast                          0.5.4
# gekko                         1.0.6
# google-auth                   2.25.2
# google-auth-oauthlib          1.2.0
# gradio                        4.10.0
# gradio_client                 0.7.3
# grpcio                        1.60.0
# h11                           0.14.0
# hdbscan                       0.8.33
# httpcore                      1.0.2
# httptools                     0.6.1
# httpx                         0.25.2
# huggingface-hub               0.20.1
# humanfriendly                 10.0
# idna                          3.6
# importlib-metadata            7.0.1
# importlib-resources           6.1.1
# ipykernel                     6.29.4
# ipython                       8.24.0
# isoduration                   20.11.0
# itsdangerous                  2.1.2
# jaconv                        0.3.4
# jamo                          0.4.1
# jedi                          0.19.1
# jieba                         0.42.1
# Jinja2                        3.1.2
# jmespath                      0.10.0
# joblib                        1.3.2
# json5                         0.9.25
# jsonpatch                     1.33
# jsonpointer                   2.4
# jsonschema                    4.20.0
# jsonschema-specifications     2023.11.2
# jupyter_client                8.6.1
# jupyter_core                  5.7.2
# jupyter-events                0.10.0
# jupyter-lsp                   2.2.5
# jupyter_server                2.14.0
# jupyter_server_terminals      0.5.3
# jupyterlab                    4.1.8
# jupyterlab_pygments           0.3.0
# jupyterlab_server             2.27.1
# kaldiio                       2.18.0
# kiwisolver                    1.4.5
# langchain                     0.1.17
# langchain-community           0.0.37
# langchain-core                0.1.52
# langchain-openai              0.1.6
# langchain-text-splitters      0.0.1
# langsmith                     0.1.55
# lazy_loader                   0.3
# librosa                       0.10.1
# llama_cpp_python              0.2.23
# llvmlite                      0.41.1
# loguru                        0.7.2
# Markdown                      3.5.1
# markdown-it-py                3.0.0
# MarkupSafe                    2.1.3
# marshmallow                   3.21.2
# matplotlib                    3.8.2
# matplotlib-inline             0.1.7
# mdurl                         0.1.2
# mistune                       3.0.2
# modelscope                    1.10.0
# mpmath                        1.3.0
# msgpack                       1.0.7
# multidict                     6.0.4
# multiprocess                  0.70.15
# mypy-extensions               1.0.0
# nbclient                      0.10.0
# nbconvert                     7.16.4
# nbformat                      5.10.4
# nest-asyncio                  1.6.0
# networkx                      3.2.1
# nltk                          3.8.1
# notebook                      7.1.3
# notebook_shim                 0.2.4
# numba                         0.58.1
# numpy                         1.26.2
# oauthlib                      3.2.2
# openai                        1.26.0
# optimum                       1.16.1
# orjson                        3.10.3
# oss2                          2.18.3
# overrides                     7.7.0
# packaging                     23.2
# pandas                        2.1.4
# pandocfilters                 1.5.1
# parso                         0.8.4
# peft                          0.7.1
# pexpect                       4.9.0
# Pillow                        10.1.0
# pip                           23.3.1
# pipx                          1.3.3
# platformdirs                  4.1.0
# pooch                         1.8.0
# prometheus_client             0.20.0
# prompt-toolkit                3.0.43
# protobuf                      4.23.4
# psutil                        5.9.7
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# pyarrow                       14.0.1
# pyarrow-hotfix                0.6
# pyasn1                        0.5.1
# pyasn1-modules                0.3.0
# pycparser                     2.21
# pycryptodome                  3.19.0
# pydantic                      2.5.2
# pydantic_core                 2.14.5
# pydantic-extra-types          2.2.0
# pydantic-settings             2.1.0
# pydub                         0.25.1
# Pygments                      2.17.2
# pynndescent                   0.5.11
# pyparsing                     3.1.1
# python-dateutil               2.8.2
# python-dotenv                 1.0.0
# python-json-logger            2.0.7
# python-multipart              0.0.6
# pytorch-wpe                   0.0.1
# pytz                          2023.3.post1
# PyYAML                        6.0.1
# pyzmq                         26.0.3
# referencing                   0.32.0
# regex                         2023.10.3
# requests                      2.31.0
# requests-oauthlib             1.3.1
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rich                          13.7.0
# rouge                         1.0.1
# rpds-py                       0.15.2
# rsa                           4.9
# safetensors                   0.4.1
# scikit-learn                  1.3.2
# scipy                         1.11.4
# semantic-version              2.10.0
# Send2Trash                    1.8.3
# sentence-transformers         2.2.2
# sentencepiece                 0.1.99
# setuptools                    68.2.2
# shellingham                   1.5.4
# simplejson                    3.19.2
# six                           1.16.0
# sniffio                       1.3.0
# sortedcontainers              2.4.0
# soundfile                     0.12.1
# soupsieve                     2.5
# soxr                          0.3.7
# SQLAlchemy                    2.0.30
# sse-starlette                 1.8.2
# stack-data                    0.6.3
# starlette                     0.27.0
# starlette-context             0.3.6
# sympy                         1.12
# tabulate                      0.9.0
# tenacity                      8.3.0
# tensorboard                   2.15.1
# tensorboard-data-server       0.7.2
# terminado                     0.18.1
# threadpoolctl                 3.2.0
# tiktoken                      0.5.2
# tinycss2                      1.3.0
# tokenizers                    0.15.0
# tomli                         2.0.1
# tomlkit                       0.12.0
# toolz                         0.12.0
# torch                         2.3.0.dev20231217
# torch-complex                 0.4.3
# torchaudio                    2.2.0.dev20231217
# torchvision                   0.18.0.dev20231217
# tornado                       6.4
# tqdm                          4.66.1
# traitlets                     5.14.3
# transformers                  4.36.1
# transformers-stream-generator 0.0.4
# typer                         0.9.0
# types-python-dateutil         2.9.0.20240316
# typing_extensions             4.9.0
# typing-inspect                0.9.0
# tzdata                        2023.3
# ujson                         5.9.0
# umap-learn                    0.5.5
# uri-template                  1.3.0
# urllib3                       2.1.0
# userpath                      1.9.1
# uvicorn                       0.24.0.post1
# uvloop                        0.19.0
# watchfiles                    0.21.0
# wcwidth                       0.2.13
# webcolors                     1.13
# webencodings                  0.5.1
# websocket-client              1.8.0
# websockets                    11.0.3
# Werkzeug                      3.0.1
# wheel                         0.41.2
# xxhash                        3.4.1
# yapf                          0.40.2
# yarl                          1.9.4
# zipp                          3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
import os

# 获取OpenAI API Key
openai_api_key = getpass.getpass("Enter your OpenAI API Key: ")

# 将API Key保存为环境变量
os.environ["OPENAI_API_KEY"] = openai_api_key
# Out:
# Enter your OpenAI API Key: ········

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()   # 创建模型实例

llm.invoke("what's generative ai?")  # 调用模型提问
# Out:
# AIMessage(content='Generative AI refers to a type of artificial intelligence that is capable of creating new content, such as images, text, or music, based on patterns and data it has been trained on. This type of AI can be used for a variety of applications, including content creation, design, and even storytelling. Generative AI algorithms can generate realistic and innovative content that can be used for a wide range of purposes.', response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 13, 'total_tokens': 95}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-b7b52eb5-4d20-4af8-be64-176a246d9e41-0')

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI()

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are world class technical documentation writer."),
    ("user", "{input}")
])

chain = prompt | llm

chain.invoke({"input": "what's generative ai?"})
# Out:
# AIMessage(content='Generative AI, short for Generative Artificial Intelligence, is a type of AI technology that is capable of creating new content or data based on patterns and examples from existing data. It works by learning the underlying structure and features of a dataset and then generating new, original content that resembles the input data. Generative AI can be used for a variety of tasks, such as creating realistic images, generating human-like text, composing music, or even designing new products. It is often used in creative applications, content generation, and research in fields such as machine learning, natural language processing, and computer vision.', response_metadata={'token_usage': {'completion_tokens': 120, 'prompt_tokens': 25, 'total_tokens': 145}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-167e98ae-799c-4a21-9f09-d65faa7a7e8d-0')

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from IPython.display import Markdown

llm = ChatOpenAI()

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are world class technical documentation writer."),
    ("user", "{input}")
])

output_parser = StrOutputParser()

chain = prompt | llm | output_parser

output = chain.invoke({"input": "what's generative ai?"})

display(Markdown(output))
# Out:
# Generative AI refers to artificial intelligence systems that have the ability to create new content, such as images, text, music, or even videos, that is not directly copied from existing examples but rather generated from scratch. These systems use advanced machine learning algorithms, such as deep learning, to learn patterns and structures present in the data they are trained on, and then use this knowledge to create new and original content.
#
# Generative AI has a wide range of applications, including generating realistic images, creating natural language text, composing music, and even designing products. It has the potential to revolutionize many industries by automating creative tasks and enabling new forms of artistic expression. However, there are also ethical concerns surrounding generative AI, such as the potential for misuse, bias in the generated content, and issues of intellectual property rights.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from IPython.display import Markdown

llm = ChatOpenAI(
    model_name="gpt-4-1106-preview"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are world class technical documentation writer."),
    ("user", "{input}")
])

translate_prompt = ChatPromptTemplate.from_messages([
    ("system", "Translate to simplified Chinese."),
    ("user", "{input}")
])

output_parser = StrOutputParser()

chain = prompt | llm | output_parser \
        | {"input": RunnablePassthrough()} \
        | translate_prompt | llm | output_parser

output = chain.invoke({"input": "what's generative ai?"})

display(Markdown(output))
# Out:
# 生成式人工智能是人工智能技术的一个子集，它能够生成新的内容或数据，这些内容或数据与其训练所基于的数据类似但不完全相同。与旨在识别或分类数据的判别式AI模型不同，生成式AI模型能够创造新的数据实例，例如图像、视频、文本、音乐，甚至是用于训练其他AI模型的合成数据。
#
# 两种最著名的生成模型类型是：
#
# 1. **生成对抗网络（GANs）：** 这涉及到两个神经网络，一个生成器和一个鉴别器，它们通过竞争过程同时进行训练。生成器尝试产生与真实数据无法区分的数据，而鉴别器则尝试区分真实数据和生成数据。随着时间的推移，生成器在生产逼真数据方面变得更加出色，鉴别器在区分它们方面也变得更加精准。GANs已被用于创建逼真的图像、3D模型，甚至艺术作品。
#
# 2. **变分自编码器（VAEs）：** 这些是使用稍微不同方法的生成模型，它们学会将数据编码到一个低维空间，然后再解码回原始空间。它们广泛用于数据压缩、生成和去噪。
#
# 最近，像变换器（Transformers）这样最初为自然语言处理任务设计的模型已被适配用于生成目的。它们被用在像GPT-3（生成预训练变换器3）这样的模型中，用于生成类似人类的文本，或者用在像DALL-E这样的模型中，用于根据文本描述生成图像。
#
# 生成式AI有许多应用，包括：
#
# - **内容创作：** 它可以为游戏、虚拟环境或营销材料生成独特的内容。
# - **数据增强：** 在机器学习中，它可以创建额外的训练数据以提高模型的性能，特别是当真实数据稀缺或昂贵时。
# - **药物发现：** 它可以帮助预测可能导致新药物的分子结构。
# - **媒体操纵：** 它负责深度伪造和其他形式的媒体，这些媒体很难区分真实与合成。
#
# 随着生成式AI领域的不断发展和演变，它既带来了令人兴奋的可能性，也带来了重大的伦理考虑，特别是关于媒体的真实性、滥用潜力以及对创意产业的影响。
